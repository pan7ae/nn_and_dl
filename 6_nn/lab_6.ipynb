# %% [markdown]
# # Лабораторная работа №6. Настройка рекуррентной нейросети для исследования сигналов
#
# Пан Анатолий Эдуардович<br>
# Группа 932209<br>
# Набор данных: https://www.kaggle.com/datasets/selfishgene/historical-hourly-weather-data

# %% [markdown]
# ## Загрузка набора данных из Kaggle

# %%
# Install kaggle
# !pip install -q kaggle

# %%
# Connect to Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Change directory
import os
os.chdir("/content/drive/MyDrive/Nauchka")

# %%
# Create a kaggle folder
# !mkdir -p ~/.kaggle

# Copy kaggle.json to created folder
# !cp kaggle.json ~/.kaggle/

# %%
os.chdir("/content")

# %%
# Permission for the json to act
# !chmod 600 ~/.kaggle/kaggle.json

# %%
# Download the required dataset
# !kaggle datasets download -d selfishgene/historical-hourly-weather-data
# Out:
# Downloading historical-hourly-weather-data.zip to /content
#  42% 5.00M/12.0M [00:00<00:00, 46.7MB/s]
# 100% 12.0M/12.0M [00:00<00:00, 92.3MB/s]

# %%
# Unzip our dataset
from zipfile import ZipFile
from tqdm import tqdm


file_to_extract = "/content/historical-hourly-weather-data.zip"

# Open your .zip file
with ZipFile(file=file_to_extract) as zip_file:

    # Loop over each file and extract them
    for file in tqdm(iterable=zip_file.namelist(), total=len(zip_file.namelist())):
        zip_file.extract(member=file)
# Out:
# 100%|██████████| 7/7 [00:00<00:00, 13.97it/s]

# %% [markdown]
# ## Установим необходимые библиотеки

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from keras.models import Sequential
from keras.layers import Dense, SimpleRNN, LSTM
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error, mean_absolute_error

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# Откроем необходимые данные

# %%
df = pd.read_csv("/content/temperature.csv")
df.head()
# Out:
#               datetime   Vancouver    Portland  San Francisco     Seattle  \
# 0  2012-10-01 12:00:00         NaN         NaN            NaN         NaN
# 1  2012-10-01 13:00:00  284.630000  282.080000     289.480000  281.800000
# 2  2012-10-01 14:00:00  284.629041  282.083252     289.474993  281.797217
# 3  2012-10-01 15:00:00  284.626998  282.091866     289.460618  281.789833
# 4  2012-10-01 16:00:00  284.624955  282.100481     289.446243  281.782449
#
#    Los Angeles   San Diego   Las Vegas     Phoenix  Albuquerque  ...  \
# 0          NaN         NaN         NaN         NaN          NaN  ...
# 1   291.870000  291.530000  293.410000  296.600000   285.120000  ...
# 2   291.868186  291.533501  293.403141  296.608509   285.154558  ...
# 3   291.862844  291.543355  293.392177  296.631487   285.233952  ...
# 4   291.857503  291.553209  293.381213  296.654466   285.313345  ...
#
#    Philadelphia    New York    Montreal      Boston   Beersheba  \
# 0           NaN         NaN         NaN         NaN         NaN
# 1    285.630000  288.220000  285.830000  287.170000  307.590000
# 2    285.663208  288.247676  285.834650  287.186092  307.590000
# 3    285.756824  288.326940  285.847790  287.231672  307.391513
# 4    285.850440  288.406203  285.860929  287.277251  307.145200
#
#    Tel Aviv District       Eilat  Haifa  Nahariyya  Jerusalem
# 0                NaN  309.100000    NaN        NaN        NaN
# 1         305.470000  310.580000  304.4      304.4      303.5
# 2         304.310000  310.495769  304.4      304.4      303.5
# 3         304.281841  310.411538  304.4      304.4      303.5
# 4         304.238015  310.327308  304.4      304.4      303.5
#
# [5 rows x 37 columns]

# %% [markdown]
# Посмотрим на список имеющихся городов

# %%
df.columns
# Out:
# Index(['datetime', 'Vancouver', 'Portland', 'San Francisco', 'Seattle',
#        'Los Angeles', 'San Diego', 'Las Vegas', 'Phoenix', 'Albuquerque',
#        'Denver', 'San Antonio', 'Dallas', 'Houston', 'Kansas City',
#        'Minneapolis', 'Saint Louis', 'Chicago', 'Nashville', 'Indianapolis',
#        'Atlanta', 'Detroit', 'Jacksonville', 'Charlotte', 'Miami',
#        'Pittsburgh', 'Toronto', 'Philadelphia', 'New York', 'Montreal',
#        'Boston', 'Beersheba', 'Tel Aviv District', 'Eilat', 'Haifa',
#        'Nahariyya', 'Jerusalem'],
#       dtype='object')

# %% [markdown]
# Для этой лабораторной работы я выберу город San Francisco. Удалим все остальные города

# %%
df = df[["datetime", "San Francisco"]]
df.head()
# Out:
#               datetime  San Francisco
# 0  2012-10-01 12:00:00            NaN
# 1  2012-10-01 13:00:00     289.480000
# 2  2012-10-01 14:00:00     289.474993
# 3  2012-10-01 15:00:00     289.460618
# 4  2012-10-01 16:00:00     289.446243

# %% [markdown]
# Размер датасета

# %%
df.shape
# Out:
# (45253, 2)

# %% [markdown]
# Проверим данные на пустые значения. Если таковые будут, то удалим их

# %%
df.isna().sum()
# Out:
# datetime           0
# San Francisco    793
# dtype: int64

# %%
df = df.dropna()

# %% [markdown]
# Выполним масштабирование данных

# %%
data = df["San Francisco"].values
scaler = MinMaxScaler(feature_range=(0, 1))
data = data.reshape(-1, 1)
data = scaler.fit_transform(data).flatten()

# %% [markdown]
# Выполните сглаживание данных для уменьшения отдельных значений содержащие
# статистические аномалии: для уменьшения влияния отдельных необычно больших или
# малых значений на результат вычисления
#
# Выполните обработку скользящим окном размера 20

# %%
def get_XY(data, window):
    Y_index = np.arange(window, len(data), window)
    Y = data[Y_index]
    rows_x = len(Y)
    X = data[range(window * rows_x)]
    X = np.reshape(X, (rows_x, window, 1))
    return X, Y

# %%
window = 20
X, y = get_XY(data, window)

# %% [markdown]
# Разделим наборы данных на выборку: обучающую и тестовую

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %% [markdown]
# ## 1. Простая рекуррентная нейронная сеть

# %% [markdown]
# Рекуррентная нейронная сеть (RNN) с одним слоем SimpleRNN и одним полносвязанным слоем Dense
#
# - `hidden_units` - количество нейронов в слое SimpleRNN;
# - `dense_units` - количество нейронов в полносвязанном слое Dense;
# - `input_shape` - форма входных данных. Она определяется как `(window, 1)`, что означает, что входные данные представляют временные ряды с окном размера `window`, и каждая точка данных имеет одну фичу;
# - `activation` - список из двух активационных функций. Первая активационная функция применяется к SimpleRNN слою, а вторая - к Dense слою;

# %%
def create_RNN(hidden_units, dense_units, input_shape, activation):
    model = Sequential()
    model.add(SimpleRNN(hidden_units,
                        input_shape=input_shape,
                        activation=activation[0],
                        return_sequences=False))
    model.add(Dense(units=dense_units, activation=activation[1]))

    model.compile(loss='mean_squared_error',
                  optimizer='adam',
                  metrics=['mean_absolute_error', 'mean_squared_error'])

    model.summary()
    return model

# %%
rnn_model = create_RNN(hidden_units=32,
                   dense_units=1,
                   input_shape=(window, 1),
                   activation=['relu', 'linear']
                   )
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  simple_rnn_3 (SimpleRNN)    (None, 32)                1088
#
#  dense_8 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 1121 (4.38 KB)
# Trainable params: 1121 (4.38 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Запустим обучение

# %%
history = rnn_model.fit(X_train,
                    y_train,
                    epochs=20,
                    batch_size=32,
                    verbose=1,
                    validation_split=0.2
                    )
# Out:
# Epoch 1/20
# 45/45 [==============================] - 2s 12ms/step - loss: 0.0178 - mean_absolute_error: 0.1008 - mean_squared_error: 0.0178 - val_loss: 0.0066 - val_mean_absolute_error: 0.0661 - val_mean_squared_error: 0.0066
# Epoch 2/20
# 45/45 [==============================] - 0s 6ms/step - loss: 0.0062 - mean_absolute_error: 0.0638 - mean_squared_error: 0.0062 - val_loss: 0.0057 - val_mean_absolute_error: 0.0609 - val_mean_squared_error: 0.0057
# Epoch 3/20
# 45/45 [==============================] - 0s 8ms/step - loss: 0.0054 - mean_absolute_error: 0.0592 - mean_squared_error: 0.0054 - val_loss: 0.0049 - val_mean_absolute_error: 0.0570 - val_mean_squared_error: 0.0049
# Epoch 4/20
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0045 - mean_absolute_error: 0.0538 - mean_squared_error: 0.0045 - val_loss: 0.0041 - val_mean_absolute_error: 0.0514 - val_mean_squared_error: 0.0041
# Epoch 5/20
# 45/45 [==============================] - 0s 11ms/step - loss: 0.0038 - mean_absolute_error: 0.0485 - mean_squared_error: 0.0038 - val_loss: 0.0031 - val_mean_absolute_error: 0.0440 - val_mean_squared_error: 0.0031
# Epoch 6/20
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0025 - mean_absolute_error: 0.0383 - mean_squared_error: 0.0025 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329 - val_mean_squared_error: 0.0019
# Epoch 7/20
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0016 - mean_absolute_error: 0.0298 - mean_squared_error: 0.0016 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258 - val_mean_squared_error: 0.0012
# Epoch 8/20
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0012 - mean_absolute_error: 0.0258 - mean_squared_error: 0.0012 - val_loss: 9.6194e-04 - val_mean_absolute_error: 0.0233 - val_mean_squared_error: 9.6194e-04
# Epoch 9/20
# 45/45 [==============================] - 0s 10ms/step - loss: 0.0010 - mean_absolute_error: 0.0237 - mean_squared_error: 0.0010 - val_loss: 7.9518e-04 - val_mean_absolute_error: 0.0219 - val_mean_squared_error: 7.9518e-04
# Epoch 10/20
# 45/45 [==============================] - 0s 10ms/step - loss: 9.3147e-04 - mean_absolute_error: 0.0226 - mean_squared_error: 9.3147e-04 - val_loss: 8.3090e-04 - val_mean_absolute_error: 0.0226 - val_mean_squared_error: 8.3090e-04
# Epoch 11/20
# 45/45 [==============================] - 0s 9ms/step - loss: 8.4329e-04 - mean_absolute_error: 0.0215 - mean_squared_error: 8.4329e-04 - val_loss: 6.4768e-04 - val_mean_absolute_error: 0.0198 - val_mean_squared_error: 6.4768e-04
# Epoch 12/20
# 45/45 [==============================] - 0s 10ms/step - loss: 8.2316e-04 - mean_absolute_error: 0.0216 - mean_squared_error: 8.2316e-04 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0013
# Epoch 13/20
# 45/45 [==============================] - 0s 9ms/step - loss: 8.7646e-04 - mean_absolute_error: 0.0222 - mean_squared_error: 8.7646e-04 - val_loss: 6.2792e-04 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 6.2792e-04
# Epoch 14/20
# 45/45 [==============================] - 0s 6ms/step - loss: 7.7715e-04 - mean_absolute_error: 0.0205 - mean_squared_error: 7.7715e-04 - val_loss: 6.8620e-04 - val_mean_absolute_error: 0.0201 - val_mean_squared_error: 6.8620e-04
# Epoch 15/20
# 45/45 [==============================] - 0s 7ms/step - loss: 7.1036e-04 - mean_absolute_error: 0.0196 - mean_squared_error: 7.1036e-04 - val_loss: 5.9232e-04 - val_mean_absolute_error: 0.0189 - val_mean_squared_error: 5.9232e-04
# Epoch 16/20
# 45/45 [==============================] - 0s 6ms/step - loss: 7.3232e-04 - mean_absolute_error: 0.0201 - mean_squared_error: 7.3232e-04 - val_loss: 7.0502e-04 - val_mean_absolute_error: 0.0204 - val_mean_squared_error: 7.0502e-04
# Epoch 17/20
# 45/45 [==============================] - 0s 6ms/step - loss: 6.9748e-04 - mean_absolute_error: 0.0192 - mean_squared_error: 6.9748e-04 - val_loss: 7.5277e-04 - val_mean_absolute_error: 0.0204 - val_mean_squared_error: 7.5277e-04
# Epoch 18/20
# 45/45 [==============================] - 0s 6ms/step - loss: 6.3535e-04 - mean_absolute_error: 0.0185 - mean_squared_error: 6.3535e-04 - val_loss: 6.0227e-04 - val_mean_absolute_error: 0.0187 - val_mean_squared_error: 6.0227e-04
# Epoch 19/20
# 45/45 [==============================] - 0s 7ms/step - loss: 6.3411e-04 - mean_absolute_error: 0.0186 - mean_squared_error: 6.3411e-04 - val_loss: 5.8985e-04 - val_mean_absolute_error: 0.0194 - val_mean_squared_error: 5.8985e-04
# Epoch 20/20
# 45/45 [==============================] - 0s 6ms/step - loss: 6.0999e-04 - mean_absolute_error: 0.0183 - mean_squared_error: 6.0999e-04 - val_loss: 5.5440e-04 - val_mean_absolute_error: 0.0183 - val_mean_squared_error: 5.5440e-04

# %% [markdown]
# Визуализируем результаты

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Посмотрим на значения отклонений и ошибок

# %%
def print_error(trainY, testY, train_predict, test_predict):
    # Error of predictions (train)
    train_mae = (mean_absolute_error(trainY, train_predict))
    train_mse = (mean_squared_error(trainY, train_predict))

    # Error of predictions (test)
    test_mae = (mean_absolute_error(testY, test_predict))
    test_mse = (mean_squared_error(testY, test_predict))

    return train_mae, train_mse, test_mae, test_mse

# %%
# make predictions
rnn_train_predict = rnn_model.predict(X_train)
rnn_test_predict = rnn_model.predict(X_test)
train_mae, train_mse, test_mae, test_mse = print_error(y_train, y_test, rnn_train_predict, rnn_test_predict)

# Print RMSE
print('train MAE: %.10f' % (train_mae))
print('train MSE: %.10f' % (train_mse))
print('test MAE: %.10f' % (test_mae))
print('test MSE: %.10f' % (test_mse))
# Out:
# 56/56 [==============================] - 0s 3ms/step
# 14/14 [==============================] - 0s 2ms/step
# train MAE: 0.0180545893
# train MSE: 0.0005917612
# test MAE: 0.0173467651
# test MSE: 0.0005254364

# %%
def plot_result(testY, test_predict, model):
    actual = testY
    predictions = test_predict
    rows = len(actual)
    plt.figure(figsize=(15, 6),dpi=100)
    plt.plot(range(rows), actual, linewidth=0.9)
    plt.plot(range(rows), predictions, linewidth=0.7)
    plt.legend(['Реальная температура', 'Предсказание'])
    plt.xlabel('Номер наблюдения')
    plt.ylabel('Отмасштабированная температура')
    plt.title(f'Реальная и предсказанная температура ({model})')

# %%
plot_result(y_test, rnn_test_predict, "RNN")

# %% [markdown]
# ## 2. LSTM

# %%
def create_LSTM(hidden_units, dense_units, input_shape, activation):
    model = Sequential()
    model.add(LSTM(hidden_units,
                   activation=activation[0],
                   input_shape=input_shape))
    model.add(Dense(units=dense_units, activation=activation[1]))

    model.compile(loss='mean_squared_error',
                  optimizer='adam',
                  metrics=['mean_absolute_error', 'mean_squared_error'])
    model.summary()
    return model

# %%
lstm_model = create_LSTM(hidden_units=32,
                         dense_units=1,
                         input_shape=(window, 1),
                         activation=['relu', 'linear']
                         )
# Out:
# Model: "sequential_9"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_6 (LSTM)               (None, 32)                4352
#
#  dense_9 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 4385 (17.13 KB)
# Trainable params: 4385 (17.13 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Запустим обучение

# %%
history = lstm_model.fit(X_train,
                         y_train,
                         epochs=20,
                         batch_size=32,
                         verbose=1,
                         validation_split=0.2
                         )
# Out:
# Epoch 1/20
# 45/45 [==============================] - 4s 24ms/step - loss: 0.1016 - mean_absolute_error: 0.2735 - mean_squared_error: 0.1016 - val_loss: 0.0084 - val_mean_absolute_error: 0.0773 - val_mean_squared_error: 0.0084
# Epoch 2/20
# 45/45 [==============================] - 2s 40ms/step - loss: 0.0083 - mean_absolute_error: 0.0739 - mean_squared_error: 0.0083 - val_loss: 0.0074 - val_mean_absolute_error: 0.0679 - val_mean_squared_error: 0.0074
# Epoch 3/20
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0068 - mean_absolute_error: 0.0676 - mean_squared_error: 0.0068 - val_loss: 0.0064 - val_mean_absolute_error: 0.0666 - val_mean_squared_error: 0.0064
# Epoch 4/20
# 45/45 [==============================] - 2s 37ms/step - loss: 0.0061 - mean_absolute_error: 0.0636 - mean_squared_error: 0.0061 - val_loss: 0.0059 - val_mean_absolute_error: 0.0641 - val_mean_squared_error: 0.0059
# Epoch 5/20
# 45/45 [==============================] - 1s 15ms/step - loss: 0.0053 - mean_absolute_error: 0.0591 - mean_squared_error: 0.0053 - val_loss: 0.0052 - val_mean_absolute_error: 0.0553 - val_mean_squared_error: 0.0052
# Epoch 6/20
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0042 - mean_absolute_error: 0.0519 - mean_squared_error: 0.0042 - val_loss: 0.0033 - val_mean_absolute_error: 0.0447 - val_mean_squared_error: 0.0033
# Epoch 7/20
# 45/45 [==============================] - 1s 13ms/step - loss: 0.0026 - mean_absolute_error: 0.0396 - mean_squared_error: 0.0026 - val_loss: 0.0020 - val_mean_absolute_error: 0.0372 - val_mean_squared_error: 0.0020
# Epoch 8/20
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0020 - mean_absolute_error: 0.0340 - mean_squared_error: 0.0020 - val_loss: 0.0017 - val_mean_absolute_error: 0.0317 - val_mean_squared_error: 0.0017
# Epoch 9/20
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0016 - mean_absolute_error: 0.0305 - mean_squared_error: 0.0016 - val_loss: 0.0011 - val_mean_absolute_error: 0.0256 - val_mean_squared_error: 0.0011
# Epoch 10/20
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0013 - mean_absolute_error: 0.0279 - mean_squared_error: 0.0013 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0013
# Epoch 11/20
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0012 - mean_absolute_error: 0.0267 - mean_squared_error: 0.0012 - val_loss: 8.8361e-04 - val_mean_absolute_error: 0.0232 - val_mean_squared_error: 8.8361e-04
# Epoch 12/20
# 45/45 [==============================] - 1s 12ms/step - loss: 0.0011 - mean_absolute_error: 0.0250 - mean_squared_error: 0.0011 - val_loss: 8.1998e-04 - val_mean_absolute_error: 0.0223 - val_mean_squared_error: 8.1998e-04
# Epoch 13/20
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0010 - mean_absolute_error: 0.0238 - mean_squared_error: 0.0010 - val_loss: 8.0600e-04 - val_mean_absolute_error: 0.0224 - val_mean_squared_error: 8.0600e-04
# Epoch 14/20
# 45/45 [==============================] - 1s 11ms/step - loss: 0.0010 - mean_absolute_error: 0.0238 - mean_squared_error: 0.0010 - val_loss: 7.5799e-04 - val_mean_absolute_error: 0.0215 - val_mean_squared_error: 7.5799e-04
# Epoch 15/20
# 45/45 [==============================] - 1s 12ms/step - loss: 8.2993e-04 - mean_absolute_error: 0.0218 - mean_squared_error: 8.2993e-04 - val_loss: 7.4183e-04 - val_mean_absolute_error: 0.0217 - val_mean_squared_error: 7.4183e-04
# Epoch 16/20
# 45/45 [==============================] - 1s 12ms/step - loss: 8.6011e-04 - mean_absolute_error: 0.0221 - mean_squared_error: 8.6011e-04 - val_loss: 6.4399e-04 - val_mean_absolute_error: 0.0196 - val_mean_squared_error: 6.4399e-04
# Epoch 17/20
# 45/45 [==============================] - 1s 12ms/step - loss: 8.1755e-04 - mean_absolute_error: 0.0215 - mean_squared_error: 8.1755e-04 - val_loss: 0.0010 - val_mean_absolute_error: 0.0247 - val_mean_squared_error: 0.0010
# Epoch 18/20
# 45/45 [==============================] - 1s 12ms/step - loss: 8.9211e-04 - mean_absolute_error: 0.0231 - mean_squared_error: 8.9211e-04 - val_loss: 6.2624e-04 - val_mean_absolute_error: 0.0190 - val_mean_squared_error: 6.2624e-04
# Epoch 19/20
# 45/45 [==============================] - 1s 11ms/step - loss: 8.2588e-04 - mean_absolute_error: 0.0215 - mean_squared_error: 8.2588e-04 - val_loss: 6.2956e-04 - val_mean_absolute_error: 0.0193 - val_mean_squared_error: 6.2956e-04
# Epoch 20/20
# 45/45 [==============================] - 1s 12ms/step - loss: 7.7219e-04 - mean_absolute_error: 0.0210 - mean_squared_error: 7.7219e-04 - val_loss: 9.4496e-04 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 9.4496e-04

# %% [markdown]
# Визуализируем результаты

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Посмотрим на значения отклонений и ошибок

# %%
# make predictions
lstm_train_predict = lstm_model.predict(X_train)
lstm_test_predict = lstm_model.predict(X_test)
train_mae, train_mse, test_mae, test_mse = print_error(y_train, y_test, lstm_train_predict, lstm_test_predict)

# Print RMSE
print('train MAE: %.10f' % (train_mae))
print('train MSE: %.10f' % (train_mse))
print('test MAE: %.10f' % (test_mae))
print('test MSE: %.10f' % (test_mse))
# Out:
# 56/56 [==============================] - 0s 3ms/step
# 14/14 [==============================] - 0s 4ms/step
# train MAE: 0.0237130046
# train MSE: 0.0009374382
# test MAE: 0.0217846966
# test MSE: 0.0008413669

# %%
plot_result(y_test, lstm_test_predict, "LSTM")

# %% [markdown]
# ## 3. Stacked LSTM

# %%
def create_stacked_LSTM(hidden_units, dense_units, input_shape, activation):
    model = Sequential()
    model.add(LSTM(hidden_units,
                   activation=activation[0],
                   return_sequences=True,
                   input_shape=input_shape))
    model.add(LSTM(hidden_units,
                   activation=activation[0]))
    model.add(Dense(units=dense_units, activation=activation[1]))

    model.compile(loss='mean_squared_error',
                  optimizer='adam',
                  metrics=['mean_absolute_error', 'mean_squared_error'])
    model.summary()
    return model

# %%
stacked_lstm_model = create_stacked_LSTM(hidden_units=32,
                                         dense_units=1,
                                         input_shape=(window, 1),
                                         activation=['relu', 'linear']
                                         )
# Out:
# Model: "sequential_10"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_7 (LSTM)               (None, 20, 32)            4352
#
#  lstm_8 (LSTM)               (None, 32)                8320
#
#  dense_10 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 12705 (49.63 KB)
# Trainable params: 12705 (49.63 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %% [markdown]
# Запустим обучение

# %%
history = stacked_lstm_model.fit(X_train,
                                 y_train,
                                 epochs=20,
                                 batch_size=32,
                                 verbose=1,
                                 validation_split=0.2
                                 )
# Out:
# Epoch 1/20
# 45/45 [==============================] - 4s 29ms/step - loss: 0.0481 - mean_absolute_error: 0.1682 - mean_squared_error: 0.0481 - val_loss: 0.0104 - val_mean_absolute_error: 0.0824 - val_mean_squared_error: 0.0104
# Epoch 2/20
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0106 - mean_absolute_error: 0.0829 - mean_squared_error: 0.0106 - val_loss: 0.0101 - val_mean_absolute_error: 0.0839 - val_mean_squared_error: 0.0101
# Epoch 3/20
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0094 - mean_absolute_error: 0.0791 - mean_squared_error: 0.0094 - val_loss: 0.0089 - val_mean_absolute_error: 0.0775 - val_mean_squared_error: 0.0089
# Epoch 4/20
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0084 - mean_absolute_error: 0.0752 - mean_squared_error: 0.0084 - val_loss: 0.0076 - val_mean_absolute_error: 0.0722 - val_mean_squared_error: 0.0076
# Epoch 5/20
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0066 - mean_absolute_error: 0.0648 - mean_squared_error: 0.0066 - val_loss: 0.0047 - val_mean_absolute_error: 0.0573 - val_mean_squared_error: 0.0047
# Epoch 6/20
# 45/45 [==============================] - 1s 32ms/step - loss: 0.0038 - mean_absolute_error: 0.0482 - mean_squared_error: 0.0038 - val_loss: 0.0027 - val_mean_absolute_error: 0.0410 - val_mean_squared_error: 0.0027
# Epoch 7/20
# 45/45 [==============================] - 1s 33ms/step - loss: 0.0024 - mean_absolute_error: 0.0392 - mean_squared_error: 0.0024 - val_loss: 0.0021 - val_mean_absolute_error: 0.0377 - val_mean_squared_error: 0.0021
# Epoch 8/20
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0019 - mean_absolute_error: 0.0346 - mean_squared_error: 0.0019 - val_loss: 0.0019 - val_mean_absolute_error: 0.0329 - val_mean_squared_error: 0.0019
# Epoch 9/20
# 45/45 [==============================] - 1s 20ms/step - loss: 0.0017 - mean_absolute_error: 0.0325 - mean_squared_error: 0.0017 - val_loss: 0.0014 - val_mean_absolute_error: 0.0301 - val_mean_squared_error: 0.0014
# Epoch 10/20
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0014 - mean_absolute_error: 0.0290 - mean_squared_error: 0.0014 - val_loss: 0.0013 - val_mean_absolute_error: 0.0279 - val_mean_squared_error: 0.0013
# Epoch 11/20
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0013 - mean_absolute_error: 0.0281 - mean_squared_error: 0.0013 - val_loss: 0.0012 - val_mean_absolute_error: 0.0267 - val_mean_squared_error: 0.0012
# Epoch 12/20
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0012 - val_loss: 0.0016 - val_mean_absolute_error: 0.0319 - val_mean_squared_error: 0.0016
# Epoch 13/20
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0012 - mean_absolute_error: 0.0268 - mean_squared_error: 0.0012 - val_loss: 0.0013 - val_mean_absolute_error: 0.0287 - val_mean_squared_error: 0.0013
# Epoch 14/20
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0012 - mean_absolute_error: 0.0272 - mean_squared_error: 0.0012 - val_loss: 9.7663e-04 - val_mean_absolute_error: 0.0246 - val_mean_squared_error: 9.7663e-04
# Epoch 15/20
# 45/45 [==============================] - 1s 22ms/step - loss: 0.0010 - mean_absolute_error: 0.0251 - mean_squared_error: 0.0010 - val_loss: 0.0012 - val_mean_absolute_error: 0.0280 - val_mean_squared_error: 0.0012
# Epoch 16/20
# 45/45 [==============================] - 1s 23ms/step - loss: 0.0012 - mean_absolute_error: 0.0263 - mean_squared_error: 0.0012 - val_loss: 0.0010 - val_mean_absolute_error: 0.0255 - val_mean_squared_error: 0.0010
# Epoch 17/20
# 45/45 [==============================] - 1s 21ms/step - loss: 0.0010 - mean_absolute_error: 0.0250 - mean_squared_error: 0.0010 - val_loss: 8.3159e-04 - val_mean_absolute_error: 0.0228 - val_mean_squared_error: 8.3159e-04
# Epoch 18/20
# 45/45 [==============================] - 1s 26ms/step - loss: 0.0010 - mean_absolute_error: 0.0249 - mean_squared_error: 0.0010 - val_loss: 8.6842e-04 - val_mean_absolute_error: 0.0238 - val_mean_squared_error: 8.6842e-04
# Epoch 19/20
# 45/45 [==============================] - 2s 34ms/step - loss: 9.0876e-04 - mean_absolute_error: 0.0233 - mean_squared_error: 9.0876e-04 - val_loss: 9.6915e-04 - val_mean_absolute_error: 0.0244 - val_mean_squared_error: 9.6915e-04
# Epoch 20/20
# 45/45 [==============================] - 2s 35ms/step - loss: 8.6609e-04 - mean_absolute_error: 0.0226 - mean_squared_error: 8.6609e-04 - val_loss: 8.0241e-04 - val_mean_absolute_error: 0.0216 - val_mean_squared_error: 8.0241e-04

# %% [markdown]
# Визуализируем результаты

# %%
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %% [markdown]
# Посмотрим на значения отклонений и ошибок

# %%
# make predictions
stacked_lstm_train_predict = stacked_lstm_model.predict(X_train)
stacked_lstm_test_predict = stacked_lstm_model.predict(X_test)
train_mae, train_mse, test_mae, test_mse = print_error(y_train, y_test, stacked_lstm_train_predict, stacked_lstm_test_predict)

# Print RMSE
print('train MAE: %.10f' % (train_mae))
print('train MSE: %.10f' % (train_mse))
print('test MAE: %.10f' % (test_mae))
print('test MSE: %.10f' % (test_mse))
# Out:
# 56/56 [==============================] - 1s 5ms/step
# 14/14 [==============================] - 0s 6ms/step
# train MAE: 0.0215693677
# train MSE: 0.0008332762
# test MAE: 0.0205110785
# test MSE: 0.0007366619

# %%
plot_result(y_test, lstm_test_predict, "Stacked LSTM")

# %% [markdown]
# ## Выведем все метрики

# %%
rnn = print_error(y_train, y_test, rnn_train_predict, rnn_test_predict)
lstm = print_error(y_train, y_test, lstm_train_predict, lstm_test_predict)
stacked_lstm = print_error(y_train, y_test, stacked_lstm_train_predict, stacked_lstm_test_predict)

# %%
data = [rnn, lstm, stacked_lstm]
columns = ["train MAE", "train MSE", "test MAE", "test MSE"]
index = ["rnn", "lstm", "stacked_lstm"]

df = pd.DataFrame(data, columns=columns, index=index)
df
# Out:
#               train MAE  train MSE  test MAE  test MSE
# rnn            0.018055   0.000592  0.017347  0.000525
# lstm           0.023713   0.000937  0.021785  0.000841
# stacked_lstm   0.021569   0.000833  0.020511  0.000737
